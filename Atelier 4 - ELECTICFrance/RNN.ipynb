# %% [markdown]
# # RNN

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('data.csv')
data.head()
# Out:
#          date Consomation eletric  Unnamed: 2  Unnamed: 3
# 0    1/1/2019              63,028         NaN         NaN
# 1    8/1/2019              72,241         NaN         NaN
# 2  01/15/2019              71,740         NaN         NaN
# 3  01/22/2019              77,543         NaN         NaN
# 4  01/29/2019              76,566         NaN         NaN

# %% [markdown]
# ## Formatting data

# %%
data.columns
# Out:
# Index(['date', 'Consomation eletric', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
data=data.drop(['Unnamed: 2'],axis=1)
data=data.drop(['Unnamed: 3'],axis=1)
data.dtypes
# Out:
# date                   object
# Consomation eletric    object
# dtype: object

# %%
data.head()
# Out:
#          date Consomation eletric
# 0    1/1/2019              63,028
# 1    8/1/2019              72,241
# 2  01/15/2019              71,740
# 3  01/22/2019              77,543
# 4  01/29/2019              76,566

# %%
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['date', 'Consomation eletric'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['date'],data['Consomation eletric'])

# %% [markdown]
# ## Problème
# x(t) sera basé sur x(t-1), price(today) sera basé sur price(yesterday)

# %% [markdown]
# ### 1. Normalisation

# %%
import  tensorflow as tf

# %%
import keras
from keras import layers

# %%
data.shape[1]
# Out:
# 2

# %%
model = keras.Sequential()
# Simple RNN layer
input_dim=data.shape[1]
output_dim=1
model.add(layers.SimpleRNN(units=output_dim, input_shape=(None, input_dim)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 1)                 4
#
# ...
# Total params: 4 (16.00 Byte)
# Trainable params: 4 (16.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Split Data to train and test
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(data, test_size=0.2, random_state=42)
